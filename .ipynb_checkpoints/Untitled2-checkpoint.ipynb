# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
x = torch.arange(1,21,dtype=torch.float32)
x = torch.arange(1, 21, dtype=torch.float32).view(-1, 1, 1)
y = (x.squeeze() ** 2).view(-1, 1)

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

# Training data
x = torch.arange(1, 21, dtype=torch.float32).view(-1, 1, 1).to(device)
y = (x.squeeze() ** 2).view(-1, 1).to(device)

# Model
model = SquareRNN().to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

epochs = 2000

for epoch in range(epochs):
    optimizer.zero_grad()

    output = model(x)
    loss = criterion(output, y)

    loss.backward()
    optimizer.step()

    if (epoch + 1) % 200 == 0:
        print(f"Epoch {epoch+1}, Loss={loss.item():.4f}")

# Testing
test = torch.tensor([[[20.0]]], device=device)

with torch.no_grad():
    prediction = model(test)

print("Predicted:", prediction.item())
# Out:
# Using: cuda
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       7 x = torch.arange(1, 21, dtype=torch.float32).view(-1, 1, 1).to(device)
#       8 y = (x.squeeze() ** 2).view(-1, 1).to(device)
#       9
#      10 # Model
# ---> 11 model = SquareRNN().to(device)
#      12
#      13 criterion = nn.MSELoss()
#      14 optimizer = optim.Adam(model.parameters(), lr=0.01)
#
# NameError: name 'SquareRNN' is not defined

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

# Training data
x = torch.arange(1, 301, dtype=torch.float32).view(-1, 1, 1).to(device)
y = (x.squeeze() ** 2).view(-1, 1).to(device)


class SquareRNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(1, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        x = x.squeeze(1)  # Remove sequence dimension
        return self.net(x)
# Model
model = SquareRNN().to(device)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

epochs = 5000

for epoch in range(epochs):
    optimizer.zero_grad()

    output = model(x)
    loss = criterion(output, y)

    loss.backward()
    optimizer.step()

    if (epoch + 1) % 200 == 0:
        print(f"Epoch {epoch+1}, Loss={loss.item():.4f}")

# Testing
test = torch.tensor([[[25.0]]], device=device)

with torch.no_grad():
    prediction = model(test)

print("Predicted:", prediction.item())
# Out:
# Using: cuda
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 26
#      22     def forward(self, x):
#      23         x = x.squeeze(1)  # Remove sequence dimension
#      24         return self.net(x)
#      25 # Model
# ---> 26 model = SquareRNN().to(device)
#      27
#      28 criterion = nn.MSELoss()
#      29 optimizer = optim.Adam(model.parameters(), lr=0.01)
#
# NameError: name 'SquareRNN' is not defined
